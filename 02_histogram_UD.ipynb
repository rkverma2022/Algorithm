# %%
import matplotlib.pyplot as plt

# %%
s = []
with open('02_UD_unsorted.data') as f:
    for value in f:
        s.append(value)

plt.hist(s, density = False)
plt.title("Without Sorted")
plt.show()

# %%
s = []
with open('04_UD_Merge_Sort.data') as f:
    for value in f:
        s.append(value)

plt.hist(s, density = False)
plt.title("Sorted Data Points:: Uniform Distribution")
plt.show()
